# %%
dados = np.array([149. , 160., 147., 189., 175., 168., 156., 160., 152.])

# %%
import numpy as np

# %%
alturas = np.array([160,161,162,163,164,165,166,167,168,169])

# %%
from scipy.stats import ttest_rel

# %%
alturas.mean()
# Out:
# 164.5

# %%
dados_novo = dados * 1.02
dados_novo
# Out:
# array([155.0196, 166.464 , 152.9388, 196.6356, 182.07  , 174.7872,
#        162.3024, 166.464 , 158.1408])

# %%
dados.mean(), np.std(dados)
# Out:
# (165.01333333333332, 13.042692291939664)

# %%
_, p = ttest_rel(dados, dados_novo)
p
# Out:
# 4.072922493930139e-10

# %%
alpha = 0.01

# %%
if p <= alpha:
  print('hipotese nula')
else:
  print('hipotese aceita')
# Out:
# hipotese nula
